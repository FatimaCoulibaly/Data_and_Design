# %% [markdown]
# # Community Gardens in NYC

# %%
# %matplotlib inline
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('data/NYC_Greenthumb_Community_Gardens.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 17 columns):
# PropID              273 non-null object
# Boro                536 non-null object
# Community Board     531 non-null object
# Council District    495 non-null float64
# Garden Name         536 non-null object
# Address             535 non-null object
# Size                429 non-null float64
# Jurisdiction        536 non-null object
# NeighborhoodName    323 non-null object
# Cross Streets       464 non-null object
# Latitude            429 non-null float64
# Longitude           429 non-null float64
# Postcode            431 non-null object
# Census Tract        429 non-null float64
# BIN                 431 non-null object
# BBL                 431 non-null object
# NTA                 431 non-null object
# dtypes: float64(5), object(12)
# memory usage: 71.3+ KB

# %%
df.head()
# Out:
#   PropID Boro Community Board  Council District  \
# 0    NaN    M             M03               2.0
# 1    NaN    B             B08              36.0
# 2   M382    M             M11               9.0
# 3   M331    M             M11               8.0
# 4    NaN    M             M03               2.0
#
#                            Garden Name                    Address   Size  \
# 0                11 BC Serenity Garden       626 East 11th Street  0.054
# 1  1100 Bergen Street Community Garden  1101 & 1105 Bergen Street  0.207
# 2       110th Street Block Association        1651 Madison Avenue  0.043
# 3        117th Street Community Garden         172 E 117th Street  0.080
# 4         11th Street Community Garden       422 East 11th Street  0.054
#
#   Jurisdiction NeighborhoodName                Cross Streets   Latitude  \
# 0          DPR     East Village                Avenues B & C  40.727124
# 1          PRI    Crown Heights  Nostrand & New York Avenues        NaN
# ...

# %%
df.tail()
# Out:
#     PropID Boro Community Board  Council District  \
# 531   M328    M             M10               9.0
# 532    NaN    B             B05              37.0
# 533  X164A    X             X02               NaN
# 534    NaN    B             BK4              34.0
# 535   X333    X             X04              16.0
#
#                                            Garden Name  \
# 531              William B. Washington Memorial Garden
# 532  Williams Avenue Community Garden (formerly Sha...
# 533                                Wishing Well Garden
# 534                          Woodbine St. Block Assoc.
# 535                        Woodycrest Community Garden
#
#                           Address   Size Jurisdiction NeighborhoodName  \
# 531     321-325 West 126th Street  0.090          DPR              NaN
# 532         88 Williams Avenuenue  0.126         NYRP              NaN
# 533  886 Reverend James A. Polite  0.351          DPR              NaN
# ...

# %%
df['Garden Name']. describe()
# Out:
# count            536
# unique           534
# top       El Girasol
# freq               2
# Name: Garden Name, dtype: object

# %%
df.groupby('Garden Name').count ()
# Out:
#                                                     PropID  Boro  \
# Garden Name
# 11 BC Serenity Garden                                    0     1
# 1100 Bergen Street Community Garden                      0     1
# 110th Street Block Association                           1     1
# 117th Street Community Garden                            1     1
# 11th Street Community Garden                             0     1
# 211th Street Block Association.                          0     1
# 2120 Mapes Avenue HDFC                                   0     1
# 400 Montauk Avenue Block Association. (Ismael V...       1     1
# 5th Street Slope Garden Club                             1     1
# 6/15 Green                                               0     1
# 64th Street Community Garden                             0     1
# 6BC Botanical Garden                                     1     1
# 6th Street & Avenue B Garden                             1     1
# ...

# %%
import folium

m = folium.Map(location=[40.7128, -74.0060])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[40.7128, -74.0060],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[40.7271, -73.9786],
    popup='11 BC Serenity Garden',
    icon=folium.Icon(icon='cloud')
).add_to(m)

folium.Marker(
    location=[40.6763, -73.9492],
    popup='1100 Bergen Street Community Garden',
    icon=folium.Icon(color='green', icon='star')
).add_to(m)

folium.Marker(
    location=[40.7962, -73.9473],
    popup='110 Street Block Association',
    icon=folium.Icon(color='blue')
).add_to(m)

folium.Marker(
    location=[40.7989, -73.9403],
    popup='117th Street Community Garden',
    icon=folium.Icon(color='blue', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7290, -73.9833],
    popup='11th Street Community Garden',
    icon=folium.Icon(color='red', icon='star')
).add_to(m)

folium.Marker(
    location=[40.8472, -73.8850],
    popup='2120 Mapes Avenue HDFC',
    icon=folium.Icon(color='orange', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.6687, -73.8768],
    popup='400 Montauk Avenue Block Association',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7234, -73.9809],
    popup='5th Street Slope Garden Club',
    icon=folium.Icon(color='orange', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.6647, -73.9875],
    popup='6/15 Green',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.6391, -74.0212],
    popup='64th Street Community Garden',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7240, -73.9805],
    popup='6BC Botanical Garden',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7240, -73.9819],
    popup='6th Street & Avenue B Garden	',
    icon=folium.Icon(color='green', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.6835, -73.9151],
    popup='700 Decatur Street Block Association',
    icon=folium.Icon(color='green', icon='info-sign')
).add_to(m)

folium.Marker(
location=[40.8230, -73.9164],
popup='811 Family and Friends Association',
icon=folium.Icon(color='blue', icon='cloud')
).add_to(m)

folium.Marker(
    location=[40.8111, -73.9513],
    popup='William B. Washington Memorial Garden',
    icon=folium.Icon(color='pink', icon='cloud')
).add_to(m)

folium.Marker(
    location=[40.6742, -73.9007],
    popup='Williams Avenue Community Garden',
    icon=folium.Icon(color='red', icon='star')
).add_to(m)

folium.Marker(
    location=[40.6925, -73.9167],
    popup='Woodbine St. Block Association',
    icon=folium.Icon(color='orange', icon='star')
).add_to(m)

folium.Marker(
    location=[40.8311, -73.9291],
    popup='Woodycrest Community Garden',
    icon=folium.Icon(color='blue', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.8057, -73.9156],
    popup='El Girasol',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('garden_map.html')

# %%
m = folium.Map(
    location=[40.7128, -74.0060],
    tiles='Stamen Toner',
    zoom_start=13
)

folium.Circle(
    radius=150,
    location=[40.8472, -73.8850],
    popup='2120 Mapes Avenue HDFC',
    color='crimson',
    fill=False,
).add_to(m)

folium.Circle(
    radius=150,
    location=[40.7290, -73.9833],
    popup='11th Street Community Garden',
    color='crimson',
    fill=False,
).add_to(m)

folium.CircleMarker(
    location=[40.6763, -73.9492],
    radius=50,
    popup='1100 Bergen Street Community Garden',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Cultural Institutions in NYC

# %%
institutions = pd.read_csv('data/Cultural_Institutions_by_block_and_lot.csv')

# %%
institutions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 15 columns):
# Organization Name                                               70 non-null object
# Preferred Address Line 1                                        69 non-null object
# Preferred Block-Lot Number                                      61 non-null object
# Constituency Code                                               70 non-null object
# Constituent Specific Attributes R-Secondary Type Description    68 non-null object
# Borough                                                         70 non-null object
# Postcode                                                        63 non-null float64
# Latitude                                                        63 non-null float64
# Longitude                                                       63 non-null float64
# Community Board                                                 63 non-null float64
# ...

# %%
institutions.head()
# Out:
#                    Organization Name       Preferred Address Line 1  \
# 0              Irish Hunger Memorial              Battery Park City
# 1             World Financial Center                    West Street
# 2             Synagogue for the Arts                49 White Street
# 3  Action Center To End World Hunger                6 River Terrace
# 4               Circle Line Downtown  South Street Seaport, Pier 17
#
#   Preferred Block-Lot Number Constituency Code  \
# 0                       16-1      Retail Space
# 1                        NaN      Retail Space
# 2                        NaN      Retail Space
# 3                     16-270      Retail Space
# 4                    15-7501      Retail Space
#
#   Constituent Specific Attributes R-Secondary Type Description    Borough  \
# 0                          A-Attractions & Landmarks            Manhattan
# 1                          A-Attractions & Landmarks            Manhattan
# ...

# %%
institutions.tail()
# Out:
#                           Organization Name       Preferred Address Line 1  \
# 65                            Cannon's Walk               206 Front Street
# 66  The River Vineyard Christian Fellowship         250 Greenwich Street,
# 67                  New York Public Library           175 North End Avenue
# 68                 Bike & Roll Bike Rentals  South Street Seaport, Pier 17
# 69                        NY Waterway Tours                         Pier A
#
#    Preferred Block-Lot Number Constituency Code  \
# 65                       96-5      Retail Space
# 66                      25-10      Retail Space
# 67                    16-7516      Retail Space
# 68                      73-10       Corporation
# 69                      1-Mar      Retail Space
#
#    Constituent Specific Attributes R-Secondary Type Description    Borough  \
# 65                          A-Attractions & Landmarks            Manhattan
# ...

# %%
institutions['Organization Name']. describe()
# Out:
# count              70
# unique             54
# top       Poets House
# freq                3
# Name: Organization Name, dtype: object

# %%
institutions.groupby('Organization Name').count ()
# Out:
#                                                     Preferred Address Line 1  \
# Organization Name
# "Charging Bull" at Bowling Green                                           1
# 19 Liberty Street (Federal Reserve)                                        0
# 3 Legged Dog, Inc.                                                         1
# 9/11 Memorial Preview Site                                                 1
# Action Center To End World Hunger                                          1
# African American Art Gallery                                               1
# African Burial Ground National Memorial                                    1
# American Merchant Mariners Memorial                                        1
# Battery Park Synagogue                                                     2
# Bike & Roll Bike Rentals                                                   1
# Bodies The Exhibition                                                      2
# ...

# %%
import folium

m = folium.Map(location=[40.7128, -74.0060])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[40.7128, -74.0060],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[40.7132, -74.0159],
    popup='Irish Hunger Memorial',
    icon=folium.Icon(color='red', icon='cloud')
).add_to(m)

folium.Marker(
    location=[40.6763, -73.9492],
    popup='World Financial Center',
    icon=folium.Icon(color='red', icon='star')
).add_to(m)

folium.Marker(
    location=[40.7185, -74.0041],
    popup='Synagogue for the Arts',
    icon=folium.Icon(color='red')
).add_to(m)

folium.Marker(
    location=[40.7157, -74.0165],
    popup='Action Center To End World Hunger',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7057, -74.0024],
    popup='Circle Line Downtown',
    icon=folium.Icon(color='red', icon='star')
).add_to(m)

folium.Marker(
    location=[40.7132, -74.0117],
    popup='The River Vineyard Christian Fellowship',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7156, -74.0155],
    popup='New York Public Library',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7057, -74.0024],
    popup='Bike & Roll Bike Rentals',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7044, -74.0174],
    popup='NY Waterway Tours',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7118, -74.0095],
    popup= '9/11 Memorial Preview Site',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7107, -74.0071],
    popup= 'African American Art Gallery',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.6988, -74.0397],
    popup= 'Ellis Island National Museum',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7119, -74.0058],
    popup= 'Schimmel Center for the Arts',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7058, -74.0180],
    popup= 'Museum of Jewish Heritage-A Living Memorial to the Holocaust',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7058, -74.0179],
    popup= 'The Skyscraper Museum',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7077, -74.0015],
    popup= 'Shooting Star Theater',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7042, -74.0132],
    popup= 'National Museum of the American Indian',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7069, -74.0036],
    popup= 'South Street Seaport',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7160, -74.0164],
    popup= 'Poets House',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7083, -74.0125],
    popup= 'Trinity Church',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[40.7272, -74.0108],
    popup= 'Ministry of Culture',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('cultural_institutions_map.html')

# %%
m = folium.Map(
    location=[40.7128, -74.0060],
    tiles='Stamen Toner',
    zoom_start=13
)

folium.Circle(
    radius=150,
    location=[40.7160, -74.0164],
    popup= 'Poets House',
    color='green',
    fill=False,
).add_to(m)

folium.Circle(
    radius=150,
    location=[40.7042, -74.0132],
    popup= 'National Museum of the American Indian',
    color='crimson',
    fill=False,
).add_to(m)

folium.Circle(
    radius=150,
    location=[40.7058, -74.0179],
    popup= 'The Skyscraper Museum',
    color='yellow',
    fill=False,
).add_to(m)

folium.Circle(
    radius=150,
     location=[40.7118, -74.0095],
    popup= '9/11 Memorial Preview Site',
    color='purple',
    fill=False,
).add_to(m)

folium.CircleMarker(
    location=[40.7107, -74.0071],
    radius=50,
    popup='African American Art Gallery',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('cultural_institutions_map2.html')
